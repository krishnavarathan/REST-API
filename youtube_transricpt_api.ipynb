# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnavarathan/REST-API/blob/main/youtube_transricpt_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook demonstrates how to fetch YouTube video transcripts using the `youtube-transcript-api` library. It specifically addresses IP blocking issues often encountered when running on cloud platforms by implementing a proxy configuration using `WebshareProxyConfig`. The process involves installing the necessary library, setting up the proxy with custom headers, fetching transcripts for a given video ID, and then processing the retrieved data into a pandas Series for further analysis with error handling.

# %%
# Install the YouTube Transcript API library
# !pip install youtube-transcript-api
# Out:
# Requirement already satisfied: youtube-transcript-api in /usr/local/lib/python3.12/dist-packages (1.2.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2026.1.4)

# %% [markdown]
# **Problem statememnt:** Unfortunately, YouTube has started blocking most IPs that are known to belong to cloud providers (like AWS, Google Cloud Platform, Azure, etc.), which means you will most likely run into RequestBlocked or IpBlocked exceptions when deploying your code to any cloud solutions.
#
# **Solution:** To by-pass this issue i used Webshare proxy-package. "Proxy Username" and "Proxy Password" taken from official Webshare Proxy site by creating an account.
#
# **Results:** unlimited API requets, but time latency increased.

# %%
import pandas as pd
import numpy as
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.proxies import WebshareProxyConfig
from requests import Session

http_client = Session()

# set custom header
http_client.headers.update({"Accept-Encoding": "gzip, deflate"})

# set path to CA_BUNDLE file - Removed this line as it was causing the error
# http_client.verify = "/path/to/certfile"

ytt_api = YouTubeTranscriptApi( http_client=http_client,
    proxy_config=WebshareProxyConfig(
        proxy_username="ujekszac",
        proxy_password="6ndc1xya46ow",
    )
)

# %%
print(http_client.headers)
# Out:
# {'User-Agent': 'python-requests/2.32.4', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'close', 'Accept-Language': 'en-US'}

# %%
# languages param if you want to make sure the transcripts are retrieved in your desired language
# preserve_formatting=True if you'd like to keep HTML formatting elements such as <i> (italics) and <b> (bold)

vedio_id='NyOtXBBmjLY'
try:
  res=ytt_api.fetch(vedio_id, languages=['de', 'en'], preserve_formatting=True)
  print(len(res))
except VideoUnavailable:
  print(f"VideoUnavailable Error Occured! ")
except NoTranscriptFound:
  print(f"NoTranscriptFound Error Occured! ")
except Exception as e:
  print(f"Unable to fetch the data from souce{e}")
# Out:
# 187

# %%
a=1
for i in res:
  print(f"Stanza {a} "+i.text)
  a+=1
res[-1]
a=0
# Out:
# Stanza 1 What's up everybody? Adrian, founder of
# Stanza 2 Scrape Creators, the web scraping guy
# Stanza 3 here and wanted to show you how to get
# Stanza 4 transcripts from a channel's videos on
# Stanza 5 YouTube. So here, like if we want to get
# Stanza 6 the videos, the transcripts of the
# Stanza 7 all-in podcast. Let's say we want to get
# Stanza 8 like the first 20 or 30, then I'm going
# Stanza 9 to show you how to do that and show you
# Stanza 10 how to do it fast. So we are going to be
# Stanza 11 using the scrape creators API and I
# Stanza 12 created it. It's pretty fast if I do say
# Stanza 13 so myself. So we're going to use these
# Stanza 14 two endpoints, channel videos. So that
# Stanza 15 is /v1 YouTube channel videos. You can
# Stanza 16 see the sample responses here as well as
# Stanza 17 how to make the requests. And I even
# Stanza 18 have this nice copy for AI button that
# Stanza 19 will copy the sample request and
# Stanza 20 response. And then you can plug it in a
# Stanza 21 cursor or chatbt and it can do it for
# Stanza 22 you or you can do it yourself, whatever
# Stanza 23 you like. Gives you the headers and
# Stanza 24 query parameters. So you have Yeah. So
# Stanza 25 each request needs an X API key. And you
# Stanza 26 can get that by going to
# Stanza 27 app.scrapecreators.com. And then you can
# Stanza 28 try it here if you want. Easier is in
# Stanza 29 the playground in the app if I do say so
# Stanza 30 myself. And we're also going to be using
# Stanza 31 the endpoint to get the video itself as
# Stanza 32 as well as a transcript. So to get the
# Stanza 33 transcript you just need to include get
# Stanza 34 transcript true. One of these days I
# Stanza 35 will create an endpoint or just the
# Stanza 36 transcripts to make it a little bit more
# Stanza 37 obvious. But um now you know. So I have
# Stanza 38 the code written but I will walk you
# Stanza 39 through this. First let's go over the
# Stanza 40 functions to just do the scraping. So we
# Stanza 41 broke out to uh to do the scraping broke
# Stanza 42 those out into two functions. Scrape
# Stanza 43 YouTube channel videos and scrape
# Stanza 44 YouTube video. And this obviously like
# Stanza 45 doesn't have any API limits or rate
# Stanza 46 limits or anything. So with the YouTube
# Stanza 47 API, obviously you're going to get
# Stanza 48 capped at something. With this, you're
# Stanza 49 not. You can make as many requests as
# Stanza 50 you want in as little time as you want.
# Stanza 51 And as you'll see shortly, we're going
# Stanza 52 to be uh calling all of the videos at
# Stanza 53 once to get all of their transcripts. So
# Stanza 54 in this case, we're doing 50 at once or
# Stanza 55 maybe 20 at this point. But we have the
# Stanza 56 API here that we're going to call. And
# Stanza 57 then if we have more pages, then we just
# Stanza 58 use the continuation token here. Boom.
# Stanza 59 Boom.
# Stanza 60 And what is the continuation token
# Stanza 61 actually? Channel videos. Oh, I messed
# Stanza 62 that up actually. Well, let's be honest.
# Stanza 63 Cursor mess up. So, it's not snake case
# Stanza 64 right there. It's camel case. And then,
# Stanza 65 yeah, we just include the X API key as
# Stanza 66 the header and then return response data
# Stanza 67 because we're using Axios right there.
# Stanza 68 So, for that, you just mpm install Axios
# Stanza 69 and then import it. And then scrape
# Stanza 70 YouTube video. So, we just need the URL
# Stanza 71 to the video and then get transcript
# Stanza 72 true. Ironically, I'm using snake case
# Stanza 73 there. Yeah, it's not very consistent. I
# Stanza 74 start I'm sorry about that. Um yeah and
# Stanza 75 then yeah response data and the reason
# Stanza 76 for this is because different social
# Stanza 77 medias return their stuff in in
# Stanza 78 different ways snake case or camel case
# Stanza 79 so maybe I should have just made the
# Stanza 80 executive decision to do one but is what
# Stanza 81 it is. Then we're going to store the
# Stanza 82 video ids. Scrape YouTube channel videos
# Stanza 83 doesn't give you a lot of data and
# Stanza 84 that's just because YouTube itself
# Stanza 85 doesn't return a lot of useful data. So
# Stanza 86 they'll return the views, publish time,
# Stanza 87 title and then maybe the um thumbnail
# Stanza 88 and then also the ID. But to get the
# Stanza 89 real juicy information we have to go
# Stanza 90 into each video. So that kind of stinks
# Stanza 91 but is what it is. So while the length
# Stanza 92 of the ids is less than 20, then let's
# Stanza 93 get some more ids. So because this is
# Stanza 94 named videos and a videos array is
# Stanza 95 returned, we have to go videos videos.
# Stanza 96 You could just say like videos res or
# Stanza 97 just res or something or response. Then
# Stanza 98 we're going to map all of those, get the
# Stanza 99 ids, push those into all video ids. And
# Stanza 100 if there's another continuation token we
# Stanza 101 need to continue, then do that. If not,
# Stanza 102 we're going to break out of the loop.
# Stanza 103 And then we're going to get all of the
# Stanza 104 video transcripts at once. So we're just
# Stanza 105 going to map over all of those IDs. and
# Stanza 106 then scrape the YouTube video. And then
# Stanza 107 we need to include the URL, which is
# Stanza 108 really easy. It's just
# Stanza 109 youtube.com/watch. And then the query
# Stanza 110 parameter v equals the ID. And then
# Stanza 111 we're going to log everything. See how
# Stanza 112 much time has taken to see this in
# Stanza 113 action. So let's test
# Stanza 114 scrapecreators.com.js. And let's see
# Stanza 115 what
# Stanza 116 happens. Boom. So 6 seconds, 7 seconds
# Stanza 117 to get all of the transcripts. So for 30
# Stanza 118 videos or something, that's pretty good.
# Stanza 119 And this file might be pretty slow
# Stanza 120 because it's massive. And you can see
# Stanza 121 you get the watch next videos also. And
# Stanza 122 but the transcript you can see you can
# Stanza 123 either get it as an array like broken
# Stanza 124 out into text start and end time or you
# Stanza 125 have the transcript only text which man
# Stanza 126 I just see an inconsistency as well that
# Stanza 127 this is camel case and that this is
# Stanza 128 snake case. It's terrible. I'm so sorry
# Stanza 129 about that. Yeah, future versions I'll
# Stanza 130 probably change that. So yeah, you have
# Stanza 131 the text here and it's going to be
# Stanza 132 massive. Yeah, something important to
# Stanza 133 note. These are all uh podcast episodes.
# Stanza 134 So yeah, they're absolutely massive. And
# Stanza 135 to get them all in 7 seconds, you know,
# Stanza 136 pretty pretty cool if I do say so
# Stanza 137 myself. So you can verify this yourself.
# Stanza 138 You get 100 free uh 100 free credits and
# Stanza 139 each credit is a request. So feel free
# Stanza 140 to check this out on your
# Stanza 141 own. But yeah, you get tons tons of good
# Stanza 142 data and obviously you can see the
# Stanza 143 utility of these. You could check out
# Stanza 144 which brands were mentioned, analyze
# Stanza 145 this. We also get YouTube comments as
# Stanza 146 well. So you can do that. But let's also
# Stanza 147 test this on another channel and the
# Stanza 148 handle. So that's all
# Stanza 149 in the handle is going to be Yep. Just
# Stanza 150 this right here. So without the at@
# Stanza 151 symbol. So let's say we want to scrape
# Stanza 152 bad friends another
# Stanza 153 podcast. So here's the YouTube
# Stanza 154 URL and we just want yeah that right
# Stanza 155 there.
# Stanza 156 Let's keep it at 30 also or
# Stanza 157 20 because these transcripts are
# Stanza 158 absolutely huge.
# Stanza 159 got the ids and then yeah 8 seconds a
# Stanza 160 little bit
# Stanza 161 longer but yeah so we have let's see no
# Stanza 162 more let's see we're going the videos
# Stanza 163 here no mommy yes poppy and on the
# Stanza 164 scrape creators API I believe yeah yeah
# Stanza 165 you can sort by the videos newest or
# Stanza 166 popular just like they do here and then
# Stanza 167 yeah get the chapters watch next videos
# Stanza 168 and
# Stanza 169 transcripts look at that
# Stanza 170 crazy chapters
# Stanza 171 transcripts yeah so that's So you can
# Stanza 172 sign up app.scrapers.com to get an API
# Stanza 173 key. 100 free requests. If you need
# Stanza 174 more, just let me know.
# Stanza 175 Adrianthescraping.com. And we cover
# Stanza 176 every major social media. I mean pretty
# Stanza 177 much every social media. Tik Tok,
# Stanza 178 Instagram, YouTube. Can get comments,
# Stanza 179 transcripts for all of them. Facebook,
# Stanza 180 we even do the ad libraries. So the meta
# Stanza 181 or Facebook ad library, Google ad
# Stanza 182 transparency center, LinkedIn ad
# Stanza 183 library, Twitter, including search,
# Stanza 184 followers, following, Reddit, threads,
# Stanza 185 truth social, like you name it, we got
# Stanza 186 it. So check that out.
# Stanza 187 scriptcreators.com. Thanks.

# %%
# Raw information about the snippet
res.to_raw_data()
# Out:
# [{'text': "What's up everybody? Adrian, founder of",
#   'start': 0.4,
#   'duration': 2.88},
#  {'text': 'Scrape Creators, the web scraping guy',
#   'start': 1.92,
#   'duration': 2.8},
#  {'text': 'here and wanted to show you how to get',
#   'start': 3.28,
#   'duration': 4.32},
#  {'text': "transcripts from a channel's videos on",
#   'start': 4.72,
#   'duration': 5.24},
#  {'text': 'YouTube. So here, like if we want to get',
#   'start': 7.6,
#   'duration': 4.64},
#  {'text': 'the videos, the transcripts of the',
#   'start': 9.96,
#   'duration': 3.96},
#  {'text': "all-in podcast. Let's say we want to get",
#   'start': 12.24,
#   'duration': 3.439},
#  {'text': "like the first 20 or 30, then I'm going",
#   'start': 13.92,
#   'duration': 2.8},
#  {'text': 'to show you how to do that and show you',
#   'start': 15.679,
#   'duration': 3.36},
#  {'text': 'how to do it fast. So we are going to be',
#   'start': 16.72,
#   'duration': 4.639},
#  {'text': 'using the scrape creators API and I',
#   'start': 19.039,
#   'duration': 4.16},
#  {'text': "created it. It's pretty fast if I do say",
#   'start': 21.359,
#   'duration': 3.281},
#  {'text': "so myself. So we're going to use these",
#   'start': 23.199,
#   'duration': 3.361},
#  {'text': 'two endpoints, channel videos. So that',
#   'start': 24.64,
#   'duration': 4.959},
#  {'text': 'is /v1 YouTube channel videos. You can',
#   'start': 26.56,
#   'duration': 5.2},
#  {'text': 'see the sample responses here as well as',
#   'start': 29.599,
#   'duration': 4.241},
#  {'text': 'how to make the requests. And I even',
#   'start': 31.76,
#   'duration': 4.4},
#  {'text': 'have this nice copy for AI button that',
#   'start': 33.84,
#   'duration': 4.399},
#  {'text': 'will copy the sample request and',
#   'start': 36.16,
#   'duration': 3.919},
#  {'text': 'response. And then you can plug it in a',
#   'start': 38.239,
#   'duration': 3.201},
#  {'text': 'cursor or chatbt and it can do it for',
#   'start': 40.079,
#   'duration': 2.561},
#  {'text': 'you or you can do it yourself, whatever',
#   'start': 41.44,
#   'duration': 2.88},
#  {'text': 'you like. Gives you the headers and',
#   'start': 42.64,
#   'duration': 3.759},
#  {'text': 'query parameters. So you have Yeah. So',
#   'start': 44.32,
#   'duration': 3.759},
#  {'text': 'each request needs an X API key. And you',
#   'start': 46.399,
#   'duration': 3.401},
#  {'text': 'can get that by going to', 'start': 48.079, 'duration': 3.281},
#  {'text': 'app.scrapecreators.com. And then you can',
#   'start': 49.8,
#   'duration': 3.399},
#  {'text': 'try it here if you want. Easier is in',
#   'start': 51.36,
#   'duration': 3.679},
#  {'text': 'the playground in the app if I do say so',
#   'start': 53.199,
#   'duration': 4.481},
#  {'text': "myself. And we're also going to be using",
#   'start': 55.039,
#   'duration': 5.601},
#  {'text': 'the endpoint to get the video itself as',
#   'start': 57.68,
#   'duration': 4.96},
#  {'text': 'as well as a transcript. So to get the',
#   'start': 60.64,
#   'duration': 3.28},
#  {'text': 'transcript you just need to include get',
#   'start': 62.64,
#   'duration': 3.28},
#  {'text': 'transcript true. One of these days I',
#   'start': 63.92,
#   'duration': 3.199},
#  {'text': 'will create an endpoint or just the',
#   'start': 65.92,
#   'duration': 2.72},
#  {'text': 'transcripts to make it a little bit more',
#   'start': 67.119,
#   'duration': 4.881},
#  {'text': 'obvious. But um now you know. So I have',
#   'start': 68.64,
#   'duration': 5.44},
#  {'text': 'the code written but I will walk you',
#   'start': 72.0,
#   'duration': 4.08},
#  {'text': "through this. First let's go over the",
#   'start': 74.08,
#   'duration': 5.2},
#  {'text': 'functions to just do the scraping. So we',
#   'start': 76.08,
#   'duration': 5.44},
#  {'text': 'broke out to uh to do the scraping broke',
#   'start': 79.28,
#   'duration': 3.28},
#  {'text': 'those out into two functions. Scrape',
#   'start': 81.52,
#   'duration': 2.16},
#  {'text': 'YouTube channel videos and scrape',
#   'start': 82.56,
#   'duration': 3.76},
#  {'text': 'YouTube video. And this obviously like',
#   'start': 83.68,
#   'duration': 4.16},
#  {'text': "doesn't have any API limits or rate",
#   'start': 86.32,
#   'duration': 2.88},
#  {'text': 'limits or anything. So with the YouTube',
#   'start': 87.84,
#   'duration': 2.8},
#  {'text': "API, obviously you're going to get",
#   'start': 89.2,
#   'duration': 2.72},
#  {'text': "capped at something. With this, you're",
#   'start': 90.64,
#   'duration': 2.64},
#  {'text': 'not. You can make as many requests as',
#   'start': 91.92,
#   'duration': 3.04},
#  {'text': 'you want in as little time as you want.',
#   'start': 93.28,
#   'duration': 3.36},
#  {'text': "And as you'll see shortly, we're going",
#   'start': 94.96,
#   'duration': 5.36},
#  {'text': 'to be uh calling all of the videos at',
#   'start': 96.64,
#   'duration': 5.28},
#  {'text': 'once to get all of their transcripts. So',
#   'start': 100.32,
#   'duration': 3.36},
#  {'text': "in this case, we're doing 50 at once or",
#   'start': 101.92,
#   'duration': 4.08},
#  {'text': 'maybe 20 at this point. But we have the',
#   'start': 103.68,
#   'duration': 3.92},
#  {'text': "API here that we're going to call. And",
#   'start': 106.0,
#   'duration': 4.56},
#  {'text': 'then if we have more pages, then we just',
#   'start': 107.6,
#   'duration': 5.04},
#  {'text': 'use the continuation token here. Boom.',
#   'start': 110.56,
#   'duration': 3.559},
#  {'text': 'Boom.', 'start': 112.64, 'duration': 3.92},
#  {'text': 'And what is the continuation token',
#   'start': 114.119,
#   'duration': 5.241},
#  {'text': 'actually? Channel videos. Oh, I messed',
#   'start': 116.56,
#   'duration': 4.32},
#  {'text': "that up actually. Well, let's be honest.",
#   'start': 119.36,
#   'duration': 3.84},
#  {'text': "Cursor mess up. So, it's not snake case",
#   'start': 120.88,
#   'duration': 4.32},
#  {'text': "right there. It's camel case. And then,",
#   'start': 123.2,
#   'duration': 4.0},
#  {'text': 'yeah, we just include the X API key as',
#   'start': 125.2,
#   'duration': 4.0},
#  {'text': 'the header and then return response data',
#   'start': 127.2,
#   'duration': 4.72},
#  {'text': "because we're using Axios right there.",
#   'start': 129.2,
#   'duration': 4.32},
#  {'text': 'So, for that, you just mpm install Axios',
#   'start': 131.92,
#   'duration': 3.36},
#  {'text': 'and then import it. And then scrape',
#   'start': 133.52,
#   'duration': 3.68},
#  {'text': 'YouTube video. So, we just need the URL',
#   'start': 135.28,
#   'duration': 3.36},
#  {'text': 'to the video and then get transcript',
#   'start': 137.2,
#   'duration': 3.6},
#  {'text': "true. Ironically, I'm using snake case",
#   'start': 138.64,
#   'duration': 3.76},
#  {'text': "there. Yeah, it's not very consistent. I",
#   'start': 140.8,
#   'duration': 4.88},
#  {'text': "start I'm sorry about that. Um yeah and",
#   'start': 142.4,
#   'duration': 5.28},
#  {'text': 'then yeah response data and the reason',
#   'start': 145.68,
#   'duration': 3.04},
#  {'text': 'for this is because different social',
#   'start': 147.68,
#   'duration': 2.48},
#  {'text': 'medias return their stuff in in', 'start': 148.72, 'duration': 2.8},
#  {'text': 'different ways snake case or camel case',
#   'start': 150.16,
#   'duration': 2.56},
#  {'text': 'so maybe I should have just made the',
#   'start': 151.52,
#   'duration': 3.439},
#  {'text': 'executive decision to do one but is what',
#   'start': 152.72,
#   'duration': 3.84},
#  {'text': "it is. Then we're going to store the",
#   'start': 154.959,
#   'duration': 3.92},
#  {'text': 'video ids. Scrape YouTube channel videos',
#   'start': 156.56,
#   'duration': 3.44},
#  {'text': "doesn't give you a lot of data and",
#   'start': 158.879,
#   'duration': 2.321},
#  {'text': "that's just because YouTube itself",
#   'start': 160.0,
#   'duration': 3.04},
#  {'text': "doesn't return a lot of useful data. So",
#   'start': 161.2,
#   'duration': 3.36},
#  {'text': "they'll return the views, publish time,",
#   'start': 163.04,
#   'duration': 3.76},
#  {'text': 'title and then maybe the um thumbnail',
#   'start': 164.56,
#   'duration': 4.24},
#  {'text': 'and then also the ID. But to get the',
#   'start': 166.8,
#   'duration': 3.439},
#  {'text': 'real juicy information we have to go',
#   'start': 168.8,
#   'duration': 3.36},
#  {'text': 'into each video. So that kind of stinks',
#   'start': 170.239,
#   'duration': 5.521},
#  {'text': 'but is what it is. So while the length',
#   'start': 172.16,
#   'duration': 5.04},
#  {'text': "of the ids is less than 20, then let's",
#   'start': 175.76,
#   'duration': 4.479},
#  {'text': 'get some more ids. So because this is',
#   'start': 177.2,
#   'duration': 5.119},
#  {'text': 'named videos and a videos array is',
#   'start': 180.239,
#   'duration': 3.28},
#  {'text': 'returned, we have to go videos videos.',
#   'start': 182.319,
#   'duration': 2.401},
#  {'text': 'You could just say like videos res or',
#   'start': 183.519,
#   'duration': 3.681},
#  {'text': 'just res or something or response. Then',
#   'start': 184.72,
#   'duration': 4.08},
#  {'text': "we're going to map all of those, get the",
#   'start': 187.2,
#   'duration': 3.759},
#  {'text': 'ids, push those into all video ids. And',
#   'start': 188.8,
#   'duration': 3.519},
#  {'text': "if there's another continuation token we",
#   'start': 190.959,
#   'duration': 3.2},
#  {'text': 'need to continue, then do that. If not,',
#   'start': 192.319,
#   'duration': 3.2},
#  {'text': "we're going to break out of the loop.",
#   'start': 194.159,
#   'duration': 3.201},
#  {'text': "And then we're going to get all of the",
#   'start': 195.519,
#   'duration': 3.201},
#  {'text': "video transcripts at once. So we're just",
#   'start': 197.36,
#   'duration': 3.519},
#  {'text': 'going to map over all of those IDs. and',
#   'start': 198.72,
#   'duration': 4.0},
#  {'text': 'then scrape the YouTube video. And then',
#   'start': 200.879,
#   'duration': 3.201},
#  {'text': 'we need to include the URL, which is',
#   'start': 202.72,
#   'duration': 2.84},
#  {'text': "really easy. It's just", 'start': 204.08, 'duration': 3.2},
#  {'text': 'youtube.com/watch. And then the query',
#   'start': 205.56,
#   'duration': 4.52},
#  {'text': 'parameter v equals the ID. And then',
#   'start': 207.28,
#   'duration': 4.08},
#  {'text': "we're going to log everything. See how",
#   'start': 210.08,
#   'duration': 3.439},
#  {'text': 'much time has taken to see this in',
#   'start': 211.36,
#   'duration': 5.04},
#  {'text': "action. So let's test", 'start': 213.519, 'duration': 2.881},
#  {'text': "scrapecreators.com.js. And let's see",
#   'start': 216.599,
#   'duration': 4.36},
#  {'text': 'what', 'start': 218.64, 'duration': 2.319},
#  {'text': 'happens. Boom. So 6 seconds, 7 seconds',
#   'start': 221.319,
#   'duration': 6.121},
#  {'text': 'to get all of the transcripts. So for 30',
#   'start': 225.44,
#   'duration': 3.439},
#  {'text': "videos or something, that's pretty good.",
#   'start': 227.44,
#   'duration': 2.879},
#  {'text': 'And this file might be pretty slow',
#   'start': 228.879,
#   'duration': 2.881},
#  {'text': "because it's massive. And you can see",
#   'start': 230.319,
#   'duration': 3.28},
#  {'text': 'you get the watch next videos also. And',
#   'start': 231.76,
#   'duration': 3.6},
#  {'text': 'but the transcript you can see you can',
#   'start': 233.599,
#   'duration': 3.84},
#  {'text': 'either get it as an array like broken',
#   'start': 235.36,
#   'duration': 4.32},
#  {'text': 'out into text start and end time or you',
#   'start': 237.439,
#   'duration': 5.36},
#  {'text': 'have the transcript only text which man',
#   'start': 239.68,
#   'duration': 5.36},
#  {'text': 'I just see an inconsistency as well that',
#   'start': 242.799,
#   'duration': 3.52},
#  {'text': 'this is camel case and that this is',
#   'start': 245.04,
#   'duration': 3.36},
#  {'text': "snake case. It's terrible. I'm so sorry",
#   'start': 246.319,
#   'duration': 5.28},
#  {'text': "about that. Yeah, future versions I'll",
#   'start': 248.4,
#   'duration': 4.72},
#  {'text': 'probably change that. So yeah, you have',
#   'start': 251.599,
#   'duration': 4.04},
#  {'text': "the text here and it's going to be",
#   'start': 253.12,
#   'duration': 4.48},
#  {'text': 'massive. Yeah, something important to',
#   'start': 255.639,
#   'duration': 4.201},
#  {'text': 'note. These are all uh podcast episodes.',
#   'start': 257.6,
#   'duration': 3.919},
#  {'text': "So yeah, they're absolutely massive. And",
#   'start': 259.84,
#   'duration': 3.2},
#  {'text': 'to get them all in 7 seconds, you know,',
#   'start': 261.519,
#   'duration': 3.281},
#  {'text': 'pretty pretty cool if I do say so',
#   'start': 263.04,
#   'duration': 2.96},
#  {'text': 'myself. So you can verify this yourself.',
#   'start': 264.8,
#   'duration': 4.16},
#  {'text': 'You get 100 free uh 100 free credits and',
#   'start': 266.0,
#   'duration': 5.28},
#  {'text': 'each credit is a request. So feel free',
#   'start': 268.96,
#   'duration': 4.2},
#  {'text': 'to check this out on your', 'start': 271.28, 'duration': 5.76},
#  {'text': 'own. But yeah, you get tons tons of good',
#   'start': 273.16,
#   'duration': 5.8},
#  {'text': 'data and obviously you can see the',
#   'start': 277.04,
#   'duration': 4.0},
#  {'text': 'utility of these. You could check out',
#   'start': 278.96,
#   'duration': 4.08},
#  {'text': 'which brands were mentioned, analyze',
#   'start': 281.04,
#   'duration': 3.52},
#  {'text': 'this. We also get YouTube comments as',
#   'start': 283.04,
#   'duration': 4.08},
#  {'text': "well. So you can do that. But let's also",
#   'start': 284.56,
#   'duration': 5.84},
#  {'text': 'test this on another channel and the',
#   'start': 287.12,
#   'duration': 5.72},
#  {'text': "handle. So that's all", 'start': 290.4, 'duration': 5.359},
#  {'text': 'in the handle is going to be Yep. Just',
#   'start': 292.84,
#   'duration': 5.72},
#  {'text': 'this right here. So without the at@',
#   'start': 295.759,
#   'duration': 5.281},
#  {'text': "symbol. So let's say we want to scrape",
#   'start': 298.56,
#   'duration': 6.199},
#  {'text': 'bad friends another', 'start': 301.04, 'duration': 7.48},
#  {'text': "podcast. So here's the YouTube",
#   'start': 304.759,
#   'duration': 6.841},
#  {'text': 'URL and we just want yeah that right',
#   'start': 308.52,
#   'duration': 4.6},
#  {'text': 'there.', 'start': 311.6, 'duration': 3.879},
#  {'text': "Let's keep it at 30 also or", 'start': 313.12, 'duration': 4.639},
#  {'text': '20 because these transcripts are',
#   'start': 315.479,
#   'duration': 5.681},
#  {'text': 'absolutely huge.', 'start': 317.759, 'duration': 3.401},
#  {'text': 'got the ids and then yeah 8 seconds a',
#   'start': 323.84,
#   'duration': 4.68},
#  {'text': 'little bit', 'start': 326.479, 'duration': 5.521},
#  {'text': "longer but yeah so we have let's see no",
#   'start': 328.52,
#   'duration': 5.0},
#  {'text': "more let's see we're going the videos",
#   'start': 332.0,
#   'duration': 4.24},
#  {'text': 'here no mommy yes poppy and on the',
#   'start': 333.52,
#   'duration': 4.48},
#  {'text': 'scrape creators API I believe yeah yeah',
#   'start': 336.24,
#   'duration': 3.6},
#  {'text': 'you can sort by the videos newest or',
#   'start': 338.0,
#   'duration': 4.32},
#  {'text': 'popular just like they do here and then',
#   'start': 339.84,
#   'duration': 5.199},
#  {'text': 'yeah get the chapters watch next videos',
#   'start': 342.32,
#   'duration': 4.2},
#  {'text': 'and', 'start': 345.039, 'duration': 3.961},
#  {'text': 'transcripts look at that', 'start': 346.52, 'duration': 5.04},
#  {'text': 'crazy chapters', 'start': 349.0, 'duration': 4.919},
#  {'text': "transcripts yeah so that's So you can",
#   'start': 351.56,
#   'duration': 4.44},
#  {'text': 'sign up app.scrapers.com to get an API',
#   'start': 353.919,
#   'duration': 3.761},
#  {'text': 'key. 100 free requests. If you need',
#   'start': 356.0,
#   'duration': 2.919},
#  {'text': 'more, just let me know.', 'start': 357.68, 'duration': 3.04},
#  {'text': 'Adrianthescraping.com. And we cover',
#   'start': 358.919,
#   'duration': 3.161},
#  {'text': 'every major social media. I mean pretty',
#   'start': 360.72,
#   'duration': 2.8},
#  {'text': 'much every social media. Tik Tok,',
#   'start': 362.08,
#   'duration': 3.44},
#  {'text': 'Instagram, YouTube. Can get comments,',
#   'start': 363.52,
#   'duration': 3.84},
#  {'text': 'transcripts for all of them. Facebook,',
#   'start': 365.52,
#   'duration': 3.92},
#  {'text': 'we even do the ad libraries. So the meta',
#   'start': 367.36,
#   'duration': 3.839},
#  {'text': 'or Facebook ad library, Google ad',
#   'start': 369.44,
#   'duration': 2.879},
#  {'text': 'transparency center, LinkedIn ad',
#   'start': 371.199,
#   'duration': 2.72},
#  {'text': 'library, Twitter, including search,',
#   'start': 372.319,
#   'duration': 3.041},
#  {'text': 'followers, following, Reddit, threads,',
#   'start': 373.919,
#   'duration': 2.72},
#  {'text': 'truth social, like you name it, we got',
#   'start': 375.36,
#   'duration': 2.279},
#  {'text': 'it. So check that out.', 'start': 376.639, 'duration': 4.881},
#  {'text': 'scriptcreators.com. Thanks.', 'start': 377.639, 'duration': 3.881}]

# %%
# List available transcripts
# If you want to list all transcripts which are available for a given video you can call:

transcript_list=ytt_api.list(vedio_id)
print(transcript_list)
transcript = transcript_list.find_transcript(['de', 'en'])
transcript.language
# Out:
# For this video (NyOtXBBmjLY) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - en ("English (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ar ("Arabic")
#  - zh-Hant ("Chinese (Traditional)")
#  - nl ("Dutch")
#  - fr ("French")
#  - de ("German")
#  - hi ("Hindi")
#  - id ("Indonesian")
#  - it ("Italian")
#  - ja ("Japanese")
#  - ko ("Korean")
#  - pt ("Portuguese")
#  - ru ("Russian")
#  - es ("Spanish")
#  - th ("Thai")
#  - uk ("Ukrainian")
#  - vi ("Vietnamese")
# 'English (auto-generated)'

# %%
print(transcript)
# Out:
# en ("English (auto-generated)")[TRANSLATABLE]

# %%
# filter for manually created transcripts
# transcript = transcript_list.find_manually_created_transcript(['it', 'en'])
# transcript
#  for thi vedio_id none manually_created_transcript available

# %%
print(
    transcript.video_id, '\n',
    transcript.language, '\n',
    transcript.language_code, '\n',
    # whether it has been manually created or generated by YouTube
    transcript.is_generated, '\n',
    # whether this transcript can be translated or not
    transcript.is_translatable, '\n',
    # a list of languages the transcript can be translated to
    transcript.translation_languages, '\n',
)
# Out:
# NyOtXBBmjLY
#  English (auto-generated)
#  en
#  True
#  True
#  [_TranslationLanguage(language='Arabic', language_code='ar'), _TranslationLanguage(language='Chinese (Traditional)', language_code='zh-Hant'), _TranslationLanguage(language='Dutch', language_code='nl'), _TranslationLanguage(language='French', language_code='fr'), _TranslationLanguage(language='German', language_code='de'), _TranslationLanguage(language='Hindi', language_code='hi'), _TranslationLanguage(language='Indonesian', language_code='id'), _TranslationLanguage(language='Italian', language_code='it'), _TranslationLanguage(language='Japanese', language_code='ja'), _TranslationLanguage(language='Korean', language_code='ko'), _TranslationLanguage(language='Portuguese', language_code='pt'), _TranslationLanguage(language='Russian', language_code='ru'), _TranslationLanguage(language='Spanish', language_code='es'), _TranslationLanguage(language='Thai', language_code='th'), _TranslationLanguage(language='Ukrainian', language_code='uk'), _TranslationLanguage(language='Vietnamese', language_code='vi')]

# %%
sn=transcript.fetch().snippets
text_only = [segment.text for segment in sn]
text_only
# Out:
# ["What's up everybody? Adrian, founder of",
#  'Scrape Creators, the web scraping guy',
#  'here and wanted to show you how to get',
#  "transcripts from a channel's videos on",
#  'YouTube. So here, like if we want to get',
#  'the videos, the transcripts of the',
#  "all-in podcast. Let's say we want to get",
#  "like the first 20 or 30, then I'm going",
#  'to show you how to do that and show you',
#  'how to do it fast. So we are going to be',
#  'using the scrape creators API and I',
#  "created it. It's pretty fast if I do say",
#  "so myself. So we're going to use these",
#  'two endpoints, channel videos. So that',
#  'is /v1 YouTube channel videos. You can',
#  'see the sample responses here as well as',
#  'how to make the requests. And I even',
#  'have this nice copy for AI button that',
#  'will copy the sample request and',
#  'response. And then you can plug it in a',
#  'cursor or chatbt and it can do it for',
#  'you or you can do it yourself, whatever',
#  'you like. Gives you the headers and',
#  'query parameters. So you have Yeah. So',
#  'each request needs an X API key. And you',
#  'can get that by going to',
#  'app.scrapecreators.com. And then you can',
#  'try it here if you want. Easier is in',
#  'the playground in the app if I do say so',
#  "myself. And we're also going to be using",
#  'the endpoint to get the video itself as',
#  'as well as a transcript. So to get the',
#  'transcript you just need to include get',
#  'transcript true. One of these days I',
#  'will create an endpoint or just the',
#  'transcripts to make it a little bit more',
#  'obvious. But um now you know. So I have',
#  'the code written but I will walk you',
#  "through this. First let's go over the",
#  'functions to just do the scraping. So we',
#  'broke out to uh to do the scraping broke',
#  'those out into two functions. Scrape',
#  'YouTube channel videos and scrape',
#  'YouTube video. And this obviously like',
#  "doesn't have any API limits or rate",
#  'limits or anything. So with the YouTube',
#  "API, obviously you're going to get",
#  "capped at something. With this, you're",
#  'not. You can make as many requests as',
#  'you want in as little time as you want.',
#  "And as you'll see shortly, we're going",
#  'to be uh calling all of the videos at',
#  'once to get all of their transcripts. So',
#  "in this case, we're doing 50 at once or",
#  'maybe 20 at this point. But we have the',
#  "API here that we're going to call. And",
#  'then if we have more pages, then we just',
#  'use the continuation token here. Boom.',
#  'Boom.',
#  'And what is the continuation token',
#  'actually? Channel videos. Oh, I messed',
#  "that up actually. Well, let's be honest.",
#  "Cursor mess up. So, it's not snake case",
#  "right there. It's camel case. And then,",
#  'yeah, we just include the X API key as',
#  'the header and then return response data',
#  "because we're using Axios right there.",
#  'So, for that, you just mpm install Axios',
#  'and then import it. And then scrape',
#  'YouTube video. So, we just need the URL',
#  'to the video and then get transcript',
#  "true. Ironically, I'm using snake case",
#  "there. Yeah, it's not very consistent. I",
#  "start I'm sorry about that. Um yeah and",
#  'then yeah response data and the reason',
#  'for this is because different social',
#  'medias return their stuff in in',
#  'different ways snake case or camel case',
#  'so maybe I should have just made the',
#  'executive decision to do one but is what',
#  "it is. Then we're going to store the",
#  'video ids. Scrape YouTube channel videos',
#  "doesn't give you a lot of data and",
#  "that's just because YouTube itself",
#  "doesn't return a lot of useful data. So",
#  "they'll return the views, publish time,",
#  'title and then maybe the um thumbnail',
#  'and then also the ID. But to get the',
#  'real juicy information we have to go',
#  'into each video. So that kind of stinks',
#  'but is what it is. So while the length',
#  "of the ids is less than 20, then let's",
#  'get some more ids. So because this is',
#  'named videos and a videos array is',
#  'returned, we have to go videos videos.',
#  'You could just say like videos res or',
#  'just res or something or response. Then',
#  "we're going to map all of those, get the",
#  'ids, push those into all video ids. And',
#  "if there's another continuation token we",
#  'need to continue, then do that. If not,',
#  "we're going to break out of the loop.",
#  "And then we're going to get all of the",
#  "video transcripts at once. So we're just",
#  'going to map over all of those IDs. and',
#  'then scrape the YouTube video. And then',
#  'we need to include the URL, which is',
#  "really easy. It's just",
#  'youtube.com/watch. And then the query',
#  'parameter v equals the ID. And then',
#  "we're going to log everything. See how",
#  'much time has taken to see this in',
#  "action. So let's test",
#  "scrapecreators.com.js. And let's see",
#  'what',
#  'happens. Boom. So 6 seconds, 7 seconds',
#  'to get all of the transcripts. So for 30',
#  "videos or something, that's pretty good.",
#  'And this file might be pretty slow',
#  "because it's massive. And you can see",
#  'you get the watch next videos also. And',
#  'but the transcript you can see you can',
#  'either get it as an array like broken',
#  'out into text start and end time or you',
#  'have the transcript only text which man',
#  'I just see an inconsistency as well that',
#  'this is camel case and that this is',
#  "snake case. It's terrible. I'm so sorry",
#  "about that. Yeah, future versions I'll",
#  'probably change that. So yeah, you have',
#  "the text here and it's going to be",
#  'massive. Yeah, something important to',
#  'note. These are all uh podcast episodes.',
#  "So yeah, they're absolutely massive. And",
#  'to get them all in 7 seconds, you know,',
#  'pretty pretty cool if I do say so',
#  'myself. So you can verify this yourself.',
#  'You get 100 free uh 100 free credits and',
#  'each credit is a request. So feel free',
#  'to check this out on your',
#  'own. But yeah, you get tons tons of good',
#  'data and obviously you can see the',
#  'utility of these. You could check out',
#  'which brands were mentioned, analyze',
#  'this. We also get YouTube comments as',
#  "well. So you can do that. But let's also",
#  'test this on another channel and the',
#  "handle. So that's all",
#  'in the handle is going to be Yep. Just',
#  'this right here. So without the at@',
#  "symbol. So let's say we want to scrape",
#  'bad friends another',
#  "podcast. So here's the YouTube",
#  'URL and we just want yeah that right',
#  'there.',
#  "Let's keep it at 30 also or",
#  '20 because these transcripts are',
#  'absolutely huge.',
#  'got the ids and then yeah 8 seconds a',
#  'little bit',
#  "longer but yeah so we have let's see no",
#  "more let's see we're going the videos",
#  'here no mommy yes poppy and on the',
#  'scrape creators API I believe yeah yeah',
#  'you can sort by the videos newest or',
#  'popular just like they do here and then',
#  'yeah get the chapters watch next videos',
#  'and',
#  'transcripts look at that',
#  'crazy chapters',
#  "transcripts yeah so that's So you can",
#  'sign up app.scrapers.com to get an API',
#  'key. 100 free requests. If you need',
#  'more, just let me know.',
#  'Adrianthescraping.com. And we cover',
#  'every major social media. I mean pretty',
#  'much every social media. Tik Tok,',
#  'Instagram, YouTube. Can get comments,',
#  'transcripts for all of them. Facebook,',
#  'we even do the ad libraries. So the meta',
#  'or Facebook ad library, Google ad',
#  'transparency center, LinkedIn ad',
#  'library, Twitter, including search,',
#  'followers, following, Reddit, threads,',
#  'truth social, like you name it, we got',
#  'it. So check that out.',
#  'scriptcreators.com. Thanks.']

# %%
# Fitting the transricpts data into a Series
sr=np.array(text_only)
type(sr)
se_sr=pd.Series(sr, name='Transcripts',)
se_sr
# Out:
# 0       What's up everybody? Adrian, founder of
# 1         Scrape Creators, the web scraping guy
# 2        here and wanted to show you how to get
# 3        transcripts from a channel's videos on
# 4      YouTube. So here, like if we want to get
#                          ...
# 182         library, Twitter, including search,
# 183      followers, following, Reddit, threads,
# 184      truth social, like you name it, we got
# 185                      it. So check that out.
# 186                 scriptcreators.com. Thanks.
# Name: Transcripts, Length: 187, dtype: object
